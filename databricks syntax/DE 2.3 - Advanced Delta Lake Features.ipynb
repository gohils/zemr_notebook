# %% [markdown]
# -sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px">
# </div>

# %% [markdown]
# # Advanced Delta Lake Features
#
# Now that you feel comfortable performing basic data tasks with Delta Lake, we can discuss a few features unique to Delta Lake.
#
# Note that while some of the keywords used here aren't part of standard ANSI SQL, all Delta Lake operations can be run on Databricks using SQL
#
# ## Learning Objectives
# By the end of this lesson, you should be able to:
# * Use **`OPTIMIZE`** to compact small files
# * Use **`ZORDER`** to index tables
# * Describe the directory structure of Delta Lake files
# * Review a history of table transactions
# * Query and roll back to previous table version
# * Clean up stale data files with **`VACUUM`**
#
# **Resources**
# * <a href="https://docs.databricks.com/spark/latest/spark-sql/language-manual/delta-optimize.html" target="_blank">Delta Optimize - Databricks Docs</a>
# * <a href="https://docs.databricks.com/spark/latest/spark-sql/language-manual/delta-vacuum.html" target="_blank">Delta Vacuum - Databricks Docs</a>

# %% [markdown]
# ## Run Setup
# The first thing we're going to do is run a setup script. It will define a username, userhome, and database that is scoped to each user.

# %%
# %sql
-- %run ../Includes/Classroom-Setup-02.3

# %% [markdown]
# ## Creating a Delta Table with History
#
# The cell below condenses all the transactions from the previous lesson into a single cell. (Except for the **`DROP TABLE`**!)
#
# As you're waiting for this query to run, see if you can identify the total number of transactions being executed.

# %%
# %sql
DROP TABLE IF EXISTS students;
CREATE TABLE students
  (id INT, name STRING, value DOUBLE);
  
INSERT INTO students VALUES (1, "Yve", 1.0);
INSERT INTO students VALUES (2, "Omar", 2.5);
INSERT INTO students VALUES (3, "Elia", 3.3);

INSERT INTO students
VALUES 
  (4, "Ted", 4.7),
  (5, "Tiffany", 5.5),
  (6, "Vini", 6.3);
  
UPDATE students 
SET value = value + 1
WHERE name LIKE "T%";

DELETE FROM students 
WHERE value > 6;

CREATE OR REPLACE TEMP VIEW updates(id, name, value, type) AS VALUES
  (2, "Omar", 15.2, "update"),
  (3, "", null, "delete"),
  (7, "Blue", 7.7, "insert"),
  (11, "Diya", 8.8, "update");
  
MERGE INTO students b
USING updates u
ON b.id=u.id
WHEN MATCHED AND u.type = "update"
  THEN UPDATE SET *
WHEN MATCHED AND u.type = "delete"
  THEN DELETE
WHEN NOT MATCHED AND u.type = "insert"
  THEN INSERT *;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>3</td><td>1</td><td>1</td><td>1</td></tr></tbody></table></div>

# %% [markdown]
# ## Examine Table Details
#
# Databricks uses a Hive metastore by default to register databases, tables, and views.
#
# Using **`DESCRIBE EXTENDED`** allows us to see important metadata about our table.

# %%
# %sql
DESCRIBE EXTENDED students
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>id</td><td>int</td><td></td></tr><tr><td>name</td><td>string</td><td></td></tr><tr><td>value</td><td>double</td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Partitioning</td><td></td><td></td></tr><tr><td>Not partitioned</td><td></td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Catalog</td><td>spark_catalog</td><td></td></tr><tr><td>Database</td><td>default</td><td></td></tr><tr><td>Table</td><td>students</td><td></td></tr><tr><td>Location</td><td>dbfs:/user/hive/warehouse/students</td><td></td></tr><tr><td>Provider</td><td>delta</td><td></td></tr><tr><td>Owner</td><td>root</td><td></td></tr><tr><td>Is_managed_location</td><td>true</td><td></td></tr><tr><td>Type</td><td>MANAGED</td><td></td></tr><tr><td>Table Properties</td><td>[delta.minReaderVersion=1,delta.minWriterVersion=2]</td><td></td></tr></tbody></table></div>

# %% [markdown]
# **`DESCRIBE DETAIL`** is another command that allows us to explore table metadata.

# %%
# %sql
DESCRIBE DETAIL students
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>format</th><th>id</th><th>name</th><th>description</th><th>location</th><th>createdAt</th><th>lastModified</th><th>partitionColumns</th><th>numFiles</th><th>sizeInBytes</th><th>properties</th><th>minReaderVersion</th><th>minWriterVersion</th></tr></thead><tbody><tr><td>delta</td><td>0f96770b-6578-4989-9139-a751ca122777</td><td>default.students</td><td>null</td><td>dbfs:/user/hive/warehouse/students</td><td>2022-09-03T02:49:42.924+0000</td><td>2022-09-03T02:50:16.000+0000</td><td>List()</td><td>4</td><td>4236</td><td>Map()</td><td>1</td><td>2</td></tr></tbody></table></div>

# %% [markdown]
# Note the **`Location`** field.
#
# While we've so far been thinking about our table as just a relational entity within a database, a Delta Lake table is actually backed by a collection of files stored in cloud object storage.

# %% [markdown]
# ## Explore Delta Lake Files
#
# We can see the files backing our Delta Lake table by using a Databricks Utilities function.
#
# **NOTE**: It's not important right now to know everything about these files to work with Delta Lake, but it will help you gain a greater appreciation for how the technology is implemented.

# %%
# %python
display(dbutils.fs.ls("dbfs:/user/hive/warehouse/students"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/user/hive/warehouse/students/_delta_log/</td><td>_delta_log/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/user/hive/warehouse/students/part-00000-563a82e1-9c83-4f3d-885d-eb1ff1a43b7e-c000.snappy.parquet</td><td>part-00000-563a82e1-9c83-4f3d-885d-eb1ff1a43b7e-c000.snappy.parquet</td><td>1055</td><td>1662173402000</td></tr><tr><td>dbfs:/user/hive/warehouse/students/part-00000-68a413bc-53bb-4870-a1e1-f3563b70aa06-c000.snappy.parquet</td><td>part-00000-68a413bc-53bb-4870-a1e1-f3563b70aa06-c000.snappy.parquet</td><td>1063</td><td>1662173394000</td></tr><tr><td>dbfs:/user/hive/warehouse/students/part-00000-78ee06ec-9345-4245-971f-8276655fe2ef-c000.snappy.parquet</td><td>part-00000-78ee06ec-9345-4245-971f-8276655fe2ef-c000.snappy.parquet</td><td>1055</td><td>1662173388000</td></tr><tr><td>dbfs:/user/hive/warehouse/students/part-00000-b7631d19-9292-4676-a879-8b3195a20bce-c000.snappy.parquet</td><td>part-00000-b7631d19-9292-4676-a879-8b3195a20bce-c000.snappy.parquet</td><td>1063</td><td>1662173415000</td></tr><tr><td>dbfs:/user/hive/warehouse/students/part-00000-cefeea6c-1c78-457e-a00d-5214af862f5e-c000.snappy.parquet</td><td>part-00000-cefeea6c-1c78-457e-a00d-5214af862f5e-c000.snappy.parquet</td><td>1063</td><td>1662173391000</td></tr><tr><td>dbfs:/user/hive/warehouse/students/part-00000-eb2cb7e7-389a-42e7-a505-46d059f0f464-c000.snappy.parquet</td><td>part-00000-eb2cb7e7-389a-42e7-a505-46d059f0f464-c000.snappy.parquet</td><td>1056</td><td>1662173397000</td></tr><tr><td>dbfs:/user/hive/warehouse/students/part-00001-669adf6d-b202-4798-8a16-cc662131d389-c000.snappy.parquet</td><td>part-00001-669adf6d-b202-4798-8a16-cc662131d389-c000.snappy.parquet</td><td>1084</td><td>1662173402000</td></tr><tr><td>dbfs:/user/hive/warehouse/students/part-00001-f9a8e4a4-9aed-4bbb-a6e6-28b3dcff8177-c000.snappy.parquet</td><td>part-00001-f9a8e4a4-9aed-4bbb-a6e6-28b3dcff8177-c000.snappy.parquet</td><td>1083</td><td>1662173397000</td></tr><tr><td>dbfs:/user/hive/warehouse/students/part-00002-29812432-47f4-4bc2-8107-f83b97655880-c000.snappy.parquet</td><td>part-00002-29812432-47f4-4bc2-8107-f83b97655880-c000.snappy.parquet</td><td>1063</td><td>1662173397000</td></tr><tr><td>dbfs:/user/hive/warehouse/students/part-00002-575d7cb5-0fc2-4c9f-9bff-bc74ad64b792-c000.snappy.parquet</td><td>part-00002-575d7cb5-0fc2-4c9f-9bff-bc74ad64b792-c000.snappy.parquet</td><td>1063</td><td>1662173415000</td></tr></tbody></table></div>

# %% [markdown]
# Note that our directory contains a number of Parquet data files and a directory named **`_delta_log`**.
#
# Records in Delta Lake tables are stored as data in Parquet files.
#
# Transactions to Delta Lake tables are recorded in the **`_delta_log`**.
#
# We can peek inside the **`_delta_log`** to see more.

# %%
# %python
display(dbutils.fs.ls(f"dbfs:/user/hive/warehouse/students/_delta_log"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/user/hive/warehouse/students/_delta_log/.s3-optimization-0</td><td>.s3-optimization-0</td><td>0</td><td>1662173386000</td></tr><tr><td>dbfs:/user/hive/warehouse/students/_delta_log/.s3-optimization-1</td><td>.s3-optimization-1</td><td>0</td><td>1662173387000</td></tr><tr><td>dbfs:/user/hive/warehouse/students/_delta_log/.s3-optimization-2</td><td>.s3-optimization-2</td><td>0</td><td>1662173387000</td></tr><tr><td>dbfs:/user/hive/warehouse/students/_delta_log/00000000000000000000.crc</td><td>00000000000000000000.crc</td><td>1945</td><td>1662173386000</td></tr><tr><td>dbfs:/user/hive/warehouse/students/_delta_log/00000000000000000000.json</td><td>00000000000000000000.json</td><td>997</td><td>1662173384000</td></tr><tr><td>dbfs:/user/hive/warehouse/students/_delta_log/00000000000000000001.crc</td><td>00000000000000000001.crc</td><td>1951</td><td>1662173391000</td></tr><tr><td>dbfs:/user/hive/warehouse/students/_delta_log/00000000000000000001.json</td><td>00000000000000000001.json</td><td>960</td><td>1662173389000</td></tr><tr><td>dbfs:/user/hive/warehouse/students/_delta_log/00000000000000000002.crc</td><td>00000000000000000002.crc</td><td>1951</td><td>1662173393000</td></tr><tr><td>dbfs:/user/hive/warehouse/students/_delta_log/00000000000000000002.json</td><td>00000000000000000002.json</td><td>962</td><td>1662173392000</td></tr><tr><td>dbfs:/user/hive/warehouse/students/_delta_log/00000000000000000003.crc</td><td>00000000000000000003.crc</td><td>1951</td><td>1662173397000</td></tr><tr><td>dbfs:/user/hive/warehouse/students/_delta_log/00000000000000000003.json</td><td>00000000000000000003.json</td><td>962</td><td>1662173395000</td></tr><tr><td>dbfs:/user/hive/warehouse/students/_delta_log/00000000000000000004.crc</td><td>00000000000000000004.crc</td><td>1951</td><td>1662173399000</td></tr><tr><td>dbfs:/user/hive/warehouse/students/_delta_log/00000000000000000004.json</td><td>00000000000000000004.json</td><td>1850</td><td>1662173398000</td></tr><tr><td>dbfs:/user/hive/warehouse/students/_delta_log/00000000000000000005.crc</td><td>00000000000000000005.crc</td><td>1951</td><td>1662173405000</td></tr><tr><td>dbfs:/user/hive/warehouse/students/_delta_log/00000000000000000005.json</td><td>00000000000000000005.json</td><td>2098</td><td>1662173402000</td></tr><tr><td>dbfs:/user/hive/warehouse/students/_delta_log/00000000000000000006.crc</td><td>00000000000000000006.crc</td><td>1951</td><td>1662173410000</td></tr><tr><td>dbfs:/user/hive/warehouse/students/_delta_log/00000000000000000006.json</td><td>00000000000000000006.json</td><td>1236</td><td>1662173408000</td></tr><tr><td>dbfs:/user/hive/warehouse/students/_delta_log/00000000000000000007.crc</td><td>00000000000000000007.crc</td><td>1951</td><td>1662173417000</td></tr><tr><td>dbfs:/user/hive/warehouse/students/_delta_log/00000000000000000007.json</td><td>00000000000000000007.json</td><td>2458</td><td>1662173416000</td></tr></tbody></table></div>

# %% [markdown]
# Each transaction results in a new JSON file being written to the Delta Lake transaction log. Here, we can see that there are 8 total transactions against this table (Delta Lake is 0 indexed).

# %% [markdown]
# ## Reasoning about Data Files
#
# We just saw a lot of data files for what is obviously a very small table.
#
# **`DESCRIBE DETAIL`** allows us to see some other details about our Delta table, including the number of files.

# %%
# %sql
DESCRIBE DETAIL students
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>format</th><th>id</th><th>name</th><th>description</th><th>location</th><th>createdAt</th><th>lastModified</th><th>partitionColumns</th><th>numFiles</th><th>sizeInBytes</th><th>properties</th><th>minReaderVersion</th><th>minWriterVersion</th></tr></thead><tbody><tr><td>delta</td><td>0f96770b-6578-4989-9139-a751ca122777</td><td>default.students</td><td>null</td><td>dbfs:/user/hive/warehouse/students</td><td>2022-09-03T02:49:42.924+0000</td><td>2022-09-03T02:50:16.000+0000</td><td>List()</td><td>4</td><td>4236</td><td>Map()</td><td>1</td><td>2</td></tr></tbody></table></div>

# %% [markdown]
# Here we see that our table currently contains 4 data files in its present version. So what are all those other Parquet files doing in our table directory?
#
# Rather than overwriting or immediately deleting files containing changed data, Delta Lake uses the transaction log to indicate whether or not files are valid in a current version of the table.
#
# Here, we'll look at the transaction log corresponding the **`MERGE`** statement above, where records were inserted, updated, and deleted.

# %%
# %python
display(spark.sql(f"SELECT * FROM json.`dbfs:/user/hive/warehouse/students/_delta_log/00000000000000000007.json`"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>add</th><th>commitInfo</th><th>remove</th></tr></thead><tbody><tr><td>null</td><td>null</td><td>List(true, 1662173414921, true, part-00000-cefeea6c-1c78-457e-a00d-5214af862f5e-c000.snappy.parquet, 1063, List(1662173391000000, 268435456))</td></tr><tr><td>null</td><td>null</td><td>List(true, 1662173414921, true, part-00000-68a413bc-53bb-4870-a1e1-f3563b70aa06-c000.snappy.parquet, 1063, List(1662173394000000, 268435456))</td></tr><tr><td>List(true, 1662173415000, part-00000-b7631d19-9292-4676-a879-8b3195a20bce-c000.snappy.parquet, 1063, {"numRecords":1,"minValues":{"id":2,"name":"Omar","value":15.2},"maxValues":{"id":2,"name":"Omar","value":15.2},"nullCount":{"id":0,"name":0,"value":0}}, List(1662173415000000, 268435456))</td><td>null</td><td>null</td></tr><tr><td>List(true, 1662173415000, part-00002-575d7cb5-0fc2-4c9f-9bff-bc74ad64b792-c000.snappy.parquet, 1063, {"numRecords":1,"minValues":{"id":7,"name":"Blue","value":7.7},"maxValues":{"id":7,"name":"Blue","value":7.7},"nullCount":{"id":0,"name":0,"value":0}}, List(1662173415000001, 268435456))</td><td>null</td><td>null</td></tr><tr><td>null</td><td>List(0903-020818-tvev8u5p, Databricks-Runtime/10.4.x-scala2.12, false, WriteSerializable, List(2264272731307105), MERGE, List(4638, 2, 4, 0, 2, 2, 0, 1, 1, 1, 1745, 2617), List([{"predicate":"(u.type = 'update')","actionType":"update"},{"predicate":"(u.type = 'delete')","actionType":"delete"}], [{"predicate":"(u.type = 'insert')","actionType":"insert"}], (b.id = u.id)), 6, 1662173415062, ad1204d7-4854-4417-b9b4-65861edc5e3d, 1831306348665305, siddhant_gohil@yahoo.com)</td><td>null</td></tr></tbody></table></div>

# %% [markdown]
# The **`add`** column contains a list of all the new files written to our table; the **`remove`** column indicates those files that no longer should be included in our table.
#
# When we query a Delta Lake table, the query engine uses the transaction logs to resolve all the files that are valid in the current version, and ignores all other data files.

# %% [markdown]
# ## Compacting Small Files and Indexing
#
# Small files can occur for a variety of reasons; in our case, we performed a number of operations where only one or several records were inserted.
#
# Files will be combined toward an optimal size (scaled based on the size of the table) by using the **`OPTIMIZE`** command.
#
# **`OPTIMIZE`** will replace existing data files by combining records and rewriting the results.
#
# When executing **`OPTIMIZE`**, users can optionally specify one or several fields for **`ZORDER`** indexing. While the specific math of Z-order is unimportant, it speeds up data retrieval when filtering on provided fields by colocating data with similar values within data files.

# %%
# %sql
OPTIMIZE students
ZORDER BY id
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td>dbfs:/user/hive/warehouse/students</td><td>List(1, 4, List(1098, 1098, 1098.0, 1, 1098), List(1055, 1063, 1059.0, 4, 4236), 0, List(minCubeSize(107374182400), List(0, 0), List(4, 4236), 0, List(4, 4236), 1, null), 1, 4, 0, false)</td></tr></tbody></table></div>

# %% [markdown]
# Given how small our data is, **`ZORDER`** does not provide any benefit, but we can see all of the metrics that result from this operation.

# %% [markdown]
# ## Reviewing Delta Lake Transactions
#
# Because all changes to the Delta Lake table are stored in the transaction log, we can easily review the <a href="https://docs.databricks.com/spark/2.x/spark-sql/language-manual/describe-history.html" target="_blank">table history</a>.

# %%
# %sql
DESCRIBE HISTORY students
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>8</td><td>2022-09-03T02:50:26.000+0000</td><td>1831306348665305</td><td>siddhant_gohil@yahoo.com</td><td>OPTIMIZE</td><td>Map(predicate -> [], zOrderBy -> ["id"], batchId -> 0, auto -> false)</td><td>null</td><td>List(2264272731307105)</td><td>0903-020818-tvev8u5p</td><td>7</td><td>SnapshotIsolation</td><td>false</td><td>Map(numRemovedFiles -> 4, numRemovedBytes -> 4236, p25FileSize -> 1098, minFileSize -> 1098, numAddedFiles -> 1, maxFileSize -> 1098, p75FileSize -> 1098, p50FileSize -> 1098, numAddedBytes -> 1098)</td><td>null</td><td>Databricks-Runtime/10.4.x-scala2.12</td></tr><tr><td>7</td><td>2022-09-03T02:50:16.000+0000</td><td>1831306348665305</td><td>siddhant_gohil@yahoo.com</td><td>MERGE</td><td>Map(predicate -> (b.id = u.id), matchedPredicates -> [{"predicate":"(u.type = 'update')","actionType":"update"},{"predicate":"(u.type = 'delete')","actionType":"delete"}], notMatchedPredicates -> [{"predicate":"(u.type = 'insert')","actionType":"insert"}])</td><td>null</td><td>List(2264272731307105)</td><td>0903-020818-tvev8u5p</td><td>6</td><td>WriteSerializable</td><td>false</td><td>Map(numTargetRowsCopied -> 0, numTargetRowsDeleted -> 1, numTargetFilesAdded -> 2, executionTimeMs -> 4638, numTargetRowsInserted -> 1, scanTimeMs -> 2617, numTargetRowsUpdated -> 1, numOutputRows -> 2, numTargetChangeFilesAdded -> 0, numSourceRows -> 4, numTargetFilesRemoved -> 2, rewriteTimeMs -> 1745)</td><td>null</td><td>Databricks-Runtime/10.4.x-scala2.12</td></tr><tr><td>6</td><td>2022-09-03T02:50:08.000+0000</td><td>1831306348665305</td><td>siddhant_gohil@yahoo.com</td><td>DELETE</td><td>Map(predicate -> ["(spark_catalog.default.students.value > 6.0D)"])</td><td>null</td><td>List(2264272731307105)</td><td>0903-020818-tvev8u5p</td><td>5</td><td>WriteSerializable</td><td>false</td><td>Map(numRemovedFiles -> 2, numCopiedRows -> 0, numAddedChangeFiles -> 0, executionTimeMs -> 2172, numDeletedRows -> 2, scanTimeMs -> 1369, numAddedFiles -> 0, rewriteTimeMs -> 803)</td><td>null</td><td>Databricks-Runtime/10.4.x-scala2.12</td></tr><tr><td>5</td><td>2022-09-03T02:50:02.000+0000</td><td>1831306348665305</td><td>siddhant_gohil@yahoo.com</td><td>UPDATE</td><td>Map(predicate -> StartsWith(name#28551, T))</td><td>null</td><td>List(2264272731307105)</td><td>0903-020818-tvev8u5p</td><td>4</td><td>WriteSerializable</td><td>false</td><td>Map(numRemovedFiles -> 2, numCopiedRows -> 0, numAddedChangeFiles -> 0, executionTimeMs -> 2381, scanTimeMs -> 272, numAddedFiles -> 2, numUpdatedRows -> 2, rewriteTimeMs -> 2109)</td><td>null</td><td>Databricks-Runtime/10.4.x-scala2.12</td></tr><tr><td>4</td><td>2022-09-03T02:49:58.000+0000</td><td>1831306348665305</td><td>siddhant_gohil@yahoo.com</td><td>WRITE</td><td>Map(mode -> Append, partitionBy -> [])</td><td>null</td><td>List(2264272731307105)</td><td>0903-020818-tvev8u5p</td><td>3</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 3, numOutputRows -> 3, numOutputBytes -> 3202)</td><td>null</td><td>Databricks-Runtime/10.4.x-scala2.12</td></tr><tr><td>3</td><td>2022-09-03T02:49:55.000+0000</td><td>1831306348665305</td><td>siddhant_gohil@yahoo.com</td><td>WRITE</td><td>Map(mode -> Append, partitionBy -> [])</td><td>null</td><td>List(2264272731307105)</td><td>0903-020818-tvev8u5p</td><td>2</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 1, numOutputBytes -> 1063)</td><td>null</td><td>Databricks-Runtime/10.4.x-scala2.12</td></tr><tr><td>2</td><td>2022-09-03T02:49:52.000+0000</td><td>1831306348665305</td><td>siddhant_gohil@yahoo.com</td><td>WRITE</t ...

# %% [markdown]
# As expected, **`OPTIMIZE`** created another version of our table, meaning that version 8 is our most current version.
#
# Remember all of those extra data files that had been marked as removed in our transaction log? These provide us with the ability to query previous versions of our table.
#
# These time travel queries can be performed by specifying either the integer version or a timestamp.
#
# **NOTE**: In most cases, you'll use a timestamp to recreate data at a time of interest. For our demo we'll use version, as this is deterministic (whereas you may be running this demo at any time in the future).

# %%
# %sql
SELECT * 
FROM students VERSION AS OF 3
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>value</th></tr></thead><tbody><tr><td>2</td><td>Omar</td><td>2.5</td></tr><tr><td>3</td><td>Elia</td><td>3.3</td></tr><tr><td>1</td><td>Yve</td><td>1.0</td></tr></tbody></table></div>

# %% [markdown]
# What's important to note about time travel is that we're not recreating a previous state of the table by undoing transactions against our current version; rather, we're just querying all those data files that were indicated as valid as of the specified version.

# %% [markdown]
# ## Rollback Versions
#
# Suppose you're typing up query to manually delete some records from a table and you accidentally execute this query in the following state.

# %%
# %sql
DELETE FROM students
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>-1</td></tr></tbody></table></div>

# %% [markdown]
# Note that when we see a **`-1`** for number of rows affected by a delete, this means an entire directory of data has been removed.
#
# Let's confirm this below.

# %%
# %sql
SELECT * FROM students
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>value</th></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# Deleting all the records in your table is probably not a desired outcome. Luckily, we can simply rollback this commit.

# %%
# %sql
RESTORE TABLE students TO VERSION AS OF 8
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>table_size_after_restore</th><th>num_of_files_after_restore</th><th>num_removed_files</th><th>num_restored_files</th><th>removed_files_size</th><th>restored_files_size</th></tr></thead><tbody><tr><td>1098</td><td>1</td><td>0</td><td>1</td><td>0</td><td>1098</td></tr></tbody></table></div>

# %% [markdown]
# Note that a **`RESTORE`** <a href="https://docs.databricks.com/spark/latest/spark-sql/language-manual/delta-restore.html" target="_blank">command</a> is recorded as a transaction; you won't be able to completely hide the fact that you accidentally deleted all the records in the table, but you will be able to undo the operation and bring your table back to a desired state.

# %% [markdown]
# ## Cleaning Up Stale Files
#
# Databricks will automatically clean up stale files in Delta Lake tables.
#
# While Delta Lake versioning and time travel are great for querying recent versions and rolling back queries, keeping the data files for all versions of large production tables around indefinitely is very expensive (and can lead to compliance issues if PII is present).
#
# If you wish to manually purge old data files, this can be performed with the **`VACUUM`** operation.
#
# Uncomment the following cell and execute it with a retention of **`0 HOURS`** to keep only the current version:

# %%
# %sql
-- VACUUM students RETAIN 0 HOURS

# %% [markdown]
# By default, **`VACUUM`** will prevent you from deleting files less than 7 days old, just to ensure that no long-running operations are still referencing any of the files to be deleted. If you run **`VACUUM`** on a Delta table, you lose the ability time travel back to a version older than the specified data retention period.  In our demos, you may see Databricks executing code that specifies a retention of **`0 HOURS`**. This is simply to demonstrate the feature and is not typically done in production.
#
# In the following cell, we:
# 1. Turn off a check to prevent premature deletion of data files
# 1. Make sure that logging of **`VACUUM`** commands is enabled
# 1. Use the **`DRY RUN`** version of vacuum to print out all records to be deleted

# %%
# %sql
SET spark.databricks.delta.retentionDurationCheck.enabled = false;
SET spark.databricks.delta.vacuum.logging.enabled = true;

VACUUM students RETAIN 0 HOURS DRY RUN
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th></tr></thead><tbody><tr><td>dbfs:/user/hive/warehouse/students/part-00000-563a82e1-9c83-4f3d-885d-eb1ff1a43b7e-c000.snappy.parquet</td></tr><tr><td>dbfs:/user/hive/warehouse/students/part-00000-68a413bc-53bb-4870-a1e1-f3563b70aa06-c000.snappy.parquet</td></tr><tr><td>dbfs:/user/hive/warehouse/students/part-00000-78ee06ec-9345-4245-971f-8276655fe2ef-c000.snappy.parquet</td></tr><tr><td>dbfs:/user/hive/warehouse/students/part-00000-b7631d19-9292-4676-a879-8b3195a20bce-c000.snappy.parquet</td></tr><tr><td>dbfs:/user/hive/warehouse/students/part-00000-cefeea6c-1c78-457e-a00d-5214af862f5e-c000.snappy.parquet</td></tr><tr><td>dbfs:/user/hive/warehouse/students/part-00000-eb2cb7e7-389a-42e7-a505-46d059f0f464-c000.snappy.parquet</td></tr><tr><td>dbfs:/user/hive/warehouse/students/part-00001-669adf6d-b202-4798-8a16-cc662131d389-c000.snappy.parquet</td></tr><tr><td>dbfs:/user/hive/warehouse/students/part-00001-f9a8e4a4-9aed-4bbb-a6e6-28b3dcff8177-c000.snappy.parquet</td></tr><tr><td>dbfs:/user/hive/warehouse/students/part-00002-29812432-47f4-4bc2-8107-f83b97655880-c000.snappy.parquet</td></tr><tr><td>dbfs:/user/hive/warehouse/students/part-00002-575d7cb5-0fc2-4c9f-9bff-bc74ad64b792-c000.snappy.parquet</td></tr></tbody></table></div>

# %% [markdown]
# By running **`VACUUM`** and deleting the 10 files above, we will permanently remove access to versions of the table that require these files to materialize.

# %%
# %sql
VACUUM students RETAIN 0 HOURS
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th></tr></thead><tbody><tr><td>dbfs:/user/hive/warehouse/students</td></tr></tbody></table></div>

# %% [markdown]
# Check the table directory to show that files have been successfully deleted.

# %%
# %python
display(dbutils.fs.ls(f"dbfs:/user/hive/warehouse/students"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/user/hive/warehouse/students/_delta_log/</td><td>_delta_log/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/user/hive/warehouse/students/part-00000-7019d6bc-f4ca-4989-bd69-c3a3a1294dda-c000.snappy.parquet</td><td>part-00000-7019d6bc-f4ca-4989-bd69-c3a3a1294dda-c000.snappy.parquet</td><td>1098</td><td>1662173425000</td></tr></tbody></table></div>

# %% [markdown]
# Run the following cell to delete the tables and files associated with this lesson.

# %% [markdown]
# -sandbox
# &copy; 2022 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="https://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="https://help.databricks.com/">Support</a>
